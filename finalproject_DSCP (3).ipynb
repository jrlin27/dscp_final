# %%
#import section
import requests
from bs4 import BeautifulSoup
import pandas as pd
import math
from collections import Counter
import csv

# %%
headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 20_0_1; en-US; X11; Linux x86_64) AppleWebKit/537.75.14 (KHTML, like Gecko) Version/18.0.0 Safari/1500'}

# %%
data_list = []

# %%
#link to pages 
for pages in range(1,71):
  r = requests.get('https://www.lotto-8.com/listltobigbbk.asp?indexpage='+str(pages)+'&orderby=new', headers = headers)
  r.encoding = 'UTF-8' 
  soup = BeautifulSoup(r.text,'html.parser')
  lo_numbers = soup.select('[style*="border-bottom-style: dotted; border-bottom-color: #CCCCCC; font-size:36px"]')

  for td in lo_numbers:
    numbers = td.text
    data_list.append(numbers)

df = pd.DataFrame(data_list, columns=['Numbers'])

# %%
all_numbers = []

for numbers in df['Numbers']:
    for number in numbers.split(','):
        all_numbers.append(number.strip())

print(all_numbers)
# Out:
# ['01', '05', '13', '16', '23', '34', '49', '05', '06', '09', '29', '43', '45', '27', '05', '10', '12', '15', '30', '36', '26', '05', '20', '23', '38', '44', '46', '33', '05', '08', '09', '35', '38', '44', '31', '01', '19', '26', '34', '38', '43', '48', '02', '07', '09', '18', '20', '48', '14', '01', '21', '22', '29', '31', '44', '03', '10', '13', '16', '19', '21', '48', '30', '08', '09', '14', '37', '42', '46', '10', '05', '31', '38', '41', '43', '47', '28', '05', '12', '13', '27', '28', '41', '37', '07', '11', '23', '25', '27', '43', '05', '06', '08', '10', '28', '41', '43', '45', '10', '22', '23', '35', '46', '49', '02', '09', '12', '30', '31', '33', '37', '25', '04', '11', '20', '25', '32', '39', '30', '10', '19', '21', '33', '35', '47', '09', '10', '22', '26', '29', '45', '47', '41', '03', '10', '26', '35', '37', '44', '15', '02', '14', '26', '34', '40', '46', '13', '03', '11', '20', '30', '41', '45', '28', '06', '07', '10', '24', '29', '40', '16', '03', '04', '11', '12', '20', '37', '05', '15', '19', '29', '32', '39', '40', '35', '13', '17', '23', '25', '32', '41', '16', '13', '16', '18', '22', '34', '42', '14', '02', '11', '25', '26', '27', '35', '10', '15', '38', '39', '40', '45', '48', '02', '01', '05', '06', '11', '26', '46', '41', '07', '09', '14', '16', '26', '33', '27', '11', '22', '23', '30', '31', '49', '14', '07', '11', '24', '28', '33', '46', '03', '03', '08', '11', '18', '28', '47', '05', '05', '19', '25', '33', '38', '42', '41', '02', '14', '20', '21', '22', '49', '38', '03', '14', '25', '29', '44', '45', '46', '08', '13', '19', '21', '31', '45', '37', '05', '08', '19', '23', '33', '46', '48', '01', '26', '33', '36', '40', '42', '37', '07', '18', '23', '39', '41', '43', '25', '02', '08', '09', '15', '27', '31', '42', '01', '19', '23', '30', '35', '48', '45', '04', '13', '28', '33', '38', '39', '42', '10', '12', '13', '21', '40', '42', '49', '02', '03', '08', '23', '24', '27', '14', '02', '04', '18', '20', '30', '32', '10', '07', '10', '18', '23', '34', '35', '09', '06', '08', '10', '22', '27', '29', '23', '01', '05', '16', '21', '23', '25', '30', '16', '25', '27', '31', '34', '42', '06', '05', '17', '23', '24', '36', '42', '16', '05', '21', '23', '24', '40', '44', '17', '15', '21', '22', '30', '41', '42', '24', '19', '22', '29', '36', '43', '46', '30', '02', '04', '08', '19', '24', '39', '28', '05', '08', '14', '17', '20', '46', '07', '03', '11', '16', '21', '22', '39', '04', '09', '13', '32', '34', '35', '39', '01', '03', '04', '12', '16', '29', '32', '39', '06', '11', '12', '40', '47', '49', '28', '06', '09', '12', '14', '33', '47', '34', '10', '16', '22', '40', '45', '48', '31', '10', '15', '27', '32', '39', '42', '28', '08', '22', '28', '40', '41', '45', '34', '06', '21', '34', '37', '46', '49', '18', '14', '15', '20', '26', '35', '41', '36', '05', '13', '18', '24', '27', '48', '32', '10', '17', '27', '37', '44', '45', '22', '19', '20', '26', '29', '34', '39', '04', '02', '10', '19', '20', '36', '48', '37', '15', '18', '37', '39', '44', '47', '43', '11', '21', '23', '30', '36', '47', '06', '17', '24', '28', '32', '34', '40', '03', '17', '18', '19', '23', '25', '32', '26', '18', '32', '36', '43', '48', '49', '23', '11', '20', '36', '37', '42', '49', '03', '01', '14', '27', '38', '39', '47', '49', '01', '11', '13', '25', '32', '36', '30', '01', '03', '23', '25', '42', '46', '02', '05', '10', '15', '16', '26', '30', '12', '13', '14', '23', '34', '43', '49', '44', '05', '12', '18', '28', '34', '39', '24', '10', '17', '28', '34', '40', '43', '29', '02', '12', '30', '31', '44', '48', '46', '11', '13', '24', '29', '35', '43', '01', '02', '06', '07', '27', '31', '44', '28', '07', '10', '15', '21', '34', '48', '38', '07', '15', '17', '28', '36', '39', '01', '26', '32', '35', '36', '38', '49', '39', '20', '23', '25', '36', '43', '45', '38', '05', '08', '16', '27', '35', '45', '37', '04', '16', '17', '30', '38', '42', '05', '06', '23', '24', '25', '47', '49', '05', '03', '04', '10', '21', '28', '41', '15', '01', '07 ...

# %%
print(len(all_numbers))
print(type(all_numbers[0]))
# Out:
# 14686
# <class 'str'>

# %%
for i in range(len(all_numbers)):
  all_numbers[i] = int(all_numbers[i])

print(type(all_numbers[0]))
print(all_numbers)
print(len(all_numbers))

# %%
#
for i in range(1,50):
  print(i, ':',all_numbers.count(i) , ',', round(all_numbers.count(i)/len(all_numbers)*100,2), '%')

# %%
fields = ['lottery_number','count','percentage']
rows = []

for i in range(1,50):
  count = all_numbers.count(i)
  total = len(all_numbers)
  percentage = round(count/total*100,2)
  rows.append([i, count, percentage])

# %%
import matplotlib.pyplot as plt

numbers = [row[0] for row in rows]
percentages = [row[2] for row in rows]

plt.figure(figsize=(15, 6))


bars = plt.bar(numbers, percentages)

plt.xticks(numbers)
plt.ylabel(fields[2])

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#find top 7 numbers
df = pd.DataFrame(rows, columns=fields)

df_sorted = df.sort_values(by='percentage', ascending=False)
top_7 = df_sorted.head(7)

print(top_7)
# Out:
#     lottery_number  count  percentage
# 40              41    333        2.27
# 7                8    329        2.24
# 1                2    327        2.23
# 42              43    325        2.21
# 29              30    323        2.20
# 10              11    322        2.19
# 0                1    320        2.18

# %%
plt.figure(figsize=(15, 6))


bars = plt.bar(numbers, percentages)

plt.xticks(numbers)
plt.ylabel(fields[2])

for index in top_7.index:
    bars[index].set_color('orange')
    plt.text(index, percentages[index], str(numbers[index]))

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
